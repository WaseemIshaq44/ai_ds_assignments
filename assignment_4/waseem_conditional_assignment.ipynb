# %% [markdown]
# <a href="https://colab.research.google.com/github/ubaid978/AI-Notebooks/blob/main/if_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Write a program that takes a number from the user and:
#
#     Prints "Positive" if the number is greater than 0
#
#     Prints "Negative" if the number is less than 0
#
#     Prints "Zero" if the number is 0

# %%
number = int(input('Enter a number: '))
if number>0:
    print('Positive')
elif number<0:
    print('Negative')
else:
    print('Zero')
# Out:
# Enter a number:  0
# Zero

# %% [markdown]
# ## Take an integer input from the user and check:
#
#     If the number is even, print "Even number"
#
#     Otherwise, print "Odd number"

# %%
number_1 = int(input("Enter a number to check if it is even or odd: "))
if number_1%2==0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Enter a number to check if it is even or odd:  24
# Even number

# %% [markdown]
# ## Ask the user for their age.
#
#     If age is 18 or above, print "You are eligible to vote"
#
#     Else, print "You are not eligible to vote"

# %%
user_age = int(input('Enter your age: '))
if user_age>=18:
    print('You are eligible to vote')
else:
    print('You are not eligible to vote')
# Out:
# Enter your age:  28
# You are eligible to vote

# %% [markdown]
# ## Take two numbers as input and:
#
#     Print which number is larger
#
#     If both are equal, print "Both numbers are equal"

# %%
number1 = int(input('Enter first number: '))
number2 = int(input('Enter second number: '))
if number1 > number2:
    print('First number is greater than second number')
elif number2 > number1:
    print('Second number is greater than first number')
else:
    print('Both numbers are equal')
# Out:
# Enter first number:  123
# Enter second number:  32
# First number is greater than second number

# %% [markdown]
# ## Ask the user to enter their marks (0–100).
#
#     If marks are 40 or above, print "Pass"
#
#     Otherwise, print "Fail"

# %%
user_marks = int(input('Enter your marks: '))
if user_marks>= 40:
    print('Pass')
else:
    print('Fail')

# %% [markdown]
# ## Take marks as input and print the grade:
#
#     90 or above → "Grade A"
#
#     70 to 89 → "Grade B"
#
#     50 to 69 → "Grade C"
#
#     Below 50 → "Fail"

# %%
marks = int(input('Enter marks: '))
if marks>=90:
    print('Grade A')
elif marks>=70:
    print('Grade B')
elif marks>=50:
    print('Grade C')
else:
    print('Fail')
# Out:
# Enter marks:  99
# Grade A

# %% [markdown]
# ## Ask the user for a year and check:
#
#     If the year is divisible by 4 → "Leap Year"
#
#     Otherwise → "Not a Leap Year"

# %%
year = int(input('Enter a year: '))
if year%4 ==0:
    print('Leap Year')
else:
    print('Not a Leap Year')
# Out:
# Enter a year:  2000
# Leap Year

# %% [markdown]
# ## Ask the user to enter a password:
#
#     If password is "python123" → print "Access Granted"
#
#     Else → print "Access Denied"

# %%
password = 'python123'
user_password = input('Enter a password: ')
if user_password == password:
    print('Access Granted')
else:
    print('Access Denied')
# Out:
# Enter a password:  python187
# Access Denied

# %% [markdown]
# ### Ask the user for temperature in Celsius:
#
#     Above 35 → "Very Hot"
#
#     25 to 35 → "Hot"
#
#     15 to 24 → "Normal"
#
#     Below 15 → "Cold"

# %%
temperature = int(input('Enter the temperature:  '))
if temperature>35:
    print('Very Hot')
elif temperature >=25:
    print('Hot')
elif temperature >=15:
    print('Normal')
else:
    print('Cold')
# Out:
# Enter the temperature:   37
# Very Hot

# %% [markdown]
# ## Take marks from the user:
#
#     90–100 → "Excellent"
#
#     75–89 → "Very Good"
#
#     60–74 → "Good"
#
#     40–59 → "Average"
#
#     Below 40 → "Fail"

# %%
marks = int(input('Enter marks 0 to 100 : '))
if marks>=90:
    print('Excellent')
elif marks>=75:
    print('Very Good')
elif marks >=60:
    print('Good')
else:
    print('Average')
# Out:
# Enter marks 0 to 100 :  64
# Good

# %% [markdown]
# ## Ask the user for:
#
#     Two numbers
#
#     An operator (+, -, *, /)
#
#     if operator + perform addition
#     if operator - perform subtraction
#     if operator * perform multiplication
#     if operator / perform division

# %%
firstnumber = int(input('Enter a number: '))
secondnumber = int(input('Enter second number: '))
operator = input('Enter an operator(+,-,*,/): ')
if operator== '+':
    print(f'The addition of {firstnumber} and {secondnumber} is {firstnumber + secondnumber}')
elif operator== '-':
    print(f'The subraction of {firstnumber} and {secondnumber} is {firstnumber- secondnumber}')
elif operator== '*':
    print(f'The multiplication of {firstnumber} and {secondnumber} is {firstnumber* secondnumber}')
else:
    print(f'The division of {firstnumber} and {secondnumber} is {firstnumber/ secondnumber}')
# Out:
# Enter a number:  12
# Enter second number:  12
# Enter an operator(+,-,*,/):  /
# The division of 12 and 12 is 1.0

# %% [markdown]
# ## Take age as input:
#
#     Age < 13 → "Child"
#
#     13–19 → "Teenager"
#
#     20–59 → "Adult"
#
#     60 or above → "Senior Citizen"

# %%
age = int(input('Enter an age: '))
if age<13:
    print('Child')
elif age<19:
    print('Teenager')
elif age<60:
    print('Adult')
else:
    print('Senior Citizen')
# Out:
# Enter an age:  11
# Child

# %% [markdown]
# ## Login System
#
# #### Ask for:Username Password
#
#     Conditions:
#
#     If username is "admin" and password is "1234" → "Login Successful"
#
#     Else → "Invalid Credentials"

# %%
username = input('Enter ther user name: ')
password = input('Enter the password: ')
if username=='admin' and password=='1234':
    print("Login Successful")
else:
    print('Invalid Craentials')
# Out:
# Enter ther user name:  admin
# Enter the password:  1234
# Login Successful

# %% [markdown]
# ## Ask the user for a number:
#
#     If divisible by 3 and 5 → "FizzBuzz"
#
#     If divisible by only 3 → "Fizz"
#
#     If divisible by only 5 → "Buzz"
#
#     Else → "Not divisible by 3 or 5"

# %%
number = int(input('Enter a number: '))
if number%3==0 and number%5==0:
    print('FizzBuzz')
elif number%3 == 0:
    print('Fizz')
elif number%5 ==0:
    print('Buzz')
else:
    print('Not divisible by 3 or 5')
# Out:
# Enter a number:  27
# Fizz

# %% [markdown]
# ## Ask the user for:
#
#     Account balance
#
#     Withdrawal amount
#
# ## Conditions:
#
#     If balance is sufficient:
#
#     If withdrawal amount is multiple of 500 → "Transaction Successful"
#
#     Else → "Amount must be multiple of 500"
#
#     Else → "Insufficient Balance"

# %%
account_balance = 45384

# %%
withdrawl_amount = int(input('Enter the withdrawal amount: '))
if withdrawl_amount<=account_balance:
    if withdrawl_amount%500 == 0:
        print('Transaction Successful')
    else:
        print('Amount must be multiple of 500')
else:
    print('Insufficient Balance')
# Out:
# Enter the withdrawal amount:  2500
# Transaction Successful

# %% [markdown]
# ## Ask the user:
#
#     Attendance percentage
#
#     Exam fee paid (yes or no)
#
# ## Conditions:
#
#     If attendance ≥ 75:
#
#     If fee is paid → "Eligible for Exam"
#
#     Else → "Pay exam fee first"
#
#     Else → "Not eligible due to low attendance"

# %%
attendance_percentage = int(input('Enter the Attendance percentage: '))
if attendance_percentage>=75:
    exam_fee_paid = input('Is your exam fee paid (yes/no): ').lower()
    if exam_fee_paid=='yes':
        print('Eligible for Exam.')
    else:
        print('Pay exam fee first.')
else:
    print('Not eligible due to low attendance')
# Out:
# Enter the Attendance percentage:  83
# Is your exam fee paid (yes/no):  YeS
# Eligible for Exam.

# %% [markdown]
# ## Online Order System
#
#     Ask:
#
#     Order amount
#
#     User type (regular / premium)
#
# ### Conditions:
#
#     If order ≥ 1000:
#
#     Premium → 20% discount
#
#     Regular → 10% discount
#
#     Else → "No discount available"

# %%
order_amount = int(input('Enter the order amount: '))
discount=0
if order_amount>=1000:
    user_type = input('Enter the user type (regular/premium): ').lower()
    if user_type=='regular':
        discount+=order_amount*0.10
    else:
        discount+=order_amount*0.20
else:
    discount = 0
    print('No discount available ')
print(f'Your total order amount is {order_amount} and your discount is {discount}')
# Out:
# Enter the order amount:  50000
# Enter the user type (regular/premium):  regular
# Your total order amount is 50000 and your discount is 5000.0

# %% [markdown]
# ## Ask the user:
#
#     Age
#
#     Driving license (yes / no)
#
# ## Conditions:
#
#     If age ≥ 18:
#
#     If license = yes → "You can drive"
#
#     Else → "Get a driving license"
#
#     Else → "You are underage"

# %%
age = int(input('Enter your age: '))
if age>= 18:
    driving_license = input("Do you have a driving license (yes/no): ").lower()
    if driving_license == 'yes':
        print('You can drive')
    else:
        print('Get a driving license')
else:
    print('You are underage')
# Out:
# Enter your age:  26
# Do you have a driving license (yes/no):  YES
# You can drive

# %% [markdown]
# ## Ask the user:
#
#     Internet status (on / off)
#
#     Data balance (in MB)
#
# ### Conditions:
#
#     If internet is on:
#
#     If data balance > 0 → "You are connected to the internet"
#
#     Else → "No data balance"

# %%
internet_status = input('Your internet status is (on/off): ').lower()
if internet_status=='on':
    data_balance = int(input('Your data balance in MB is: '))
    if data_balance>0:
        print('You are connected to the internet')
    else:
        print("No data balance")
else:
    print('You have no internet access')
# Out:
# Your internet status is (on/off):  On
# Your data balance in MB is:  234
# You are connected to the internet

# %% [markdown]
# ## Ask the user for a password:
#
#     If password length ≥ 8:
#
#     If it contains "@" → "Strong password"
#
#     Else → "Add a special character"
#
#     Else → "Password too short"

# %%
password = input('Enter a password: ')
if len(password) >=8:
    if '@' in password:
        print('Strong password')
    else:
        print('Add a special character')
else:
    print('Password too short')
# Out:
# Enter a password:  assd@sadfs@#!$342555
# Strong password

# %% [markdown]
# ## Movie Ticket Eligibility
#
#     Ask the user:
#
#     Age
#
#     Parental permission (yes / no)
#
# ## Conditions:
#
#     If age ≥ 18:
#
#         "Ticket Allowed"
#
#     Else:
#
#     If permission is yes → "Ticket Allowed with Permission"
#
#     Else → "Ticket Not Allowed"

# %%
user_age = int(input('Enter your age: '))
if user_age>=18:
    parent_permission = input("Parent permission (yes/no): ").lower()
    if parent_permission=='yes':
        print("Ticket Allowed with Permission")
    else:
        print('Ticket Not Allowed')
else:
    print('You are under age')
# Out:
# Enter your age:  18
# Parent permission (yes/no):  no
# Ticket Not Allowed

# %% [markdown]
# ## Online Exam Access
#
#     Ask the user:
#
#     Login status (yes / no)
#
#     Webcam status (on / off)
#
# ## Conditions:
#
#     If logged in:
#
#     If webcam is on → "Exam Started"
#
#     Else → "Turn on webcam"
#
#     Else → "Please login first"

# %%
login_status = input('Your login status is (yes/no): ').lower()
if login_status == 'yes':
    webcam_status = input('Your Webcam status is (on/off): ').lower()
    if webcam_status=='on':
        print('Exam Started')
    else:
        print('Turn on webcam')  
else:
    print('Please login first')
# Out:
# Your login status is (yes/no):  yes
# Your Webcam status is (on/off):  on
# Exam Started

# %% [markdown]
# ## Bank Loan Approval
# Ask the user:
#
#     Monthly income
#
#     Credit score
#
# ### Conditions:
#
#     If income ≥ 50,000:
#
#     If credit score ≥ 700 → "Loan Approved"
#
#     Else → "Low credit score"
#
#     Else → "Income too low"

# %%
monthly_income = int(input('Enter your monthly income: '))
if monthly_income>= 50000:
    cradit_score = int(input('Enter the credit score: '))
    if cradit_score>700:
        print('Loan Approved')
    else:
        print('Low credit score')
else:
    print('Income is low')
# Out:
# Enter your monthly income:  55000
# Enter the credit score:  800
# Loan Approved

# %% [markdown]
# ## App Subscription Access
#
#     Ask the user:
#
#     Subscription type (free / premium)
#
#     Feature name (download / stream)
#
# ## Conditions:
#
#     If subscription is premium:
#
#     "Access Granted"
#
#     Else:
#
#     If feature is stream → "Access Granted"
#
#     Else → "Upgrade to Premium"

# %%
subsciption_type = input('Subscription type (free/premium): ').lower()
if subsciption_type =='premium':
    feature_name = input('Feature (download/stream): ').lower()
    if feature_name=='stream':
        print('Acces Granted')
    else:
        print('You can download the videos')
else:
    print('Upgrade to Premium.')
# Out:
# Subscription type (free/premium):  Premium
# Feature (download/stream):  StREam
# Acces Granted

# %% [markdown]
# ## Device Charging Status
#
#     Ask the user:
#
#     Charger connected (yes / no)
#
#     Battery percentage
#
# ## Conditions:
#
#     If charger connected:
#
#     If battery < 100 → "Charging"
#
#     Else → "Battery Full"
#
#     Else → "Connect charger"

# %%
charger_connected = input('Is your charger connected (yes/no): ').lower()
if charger_connected=='yes':
    battery_percentage = int(input('What is your battery percentage'))
    if battery_percentage<100:
        print('Charging')
    else:
        print('Battery Full')
else:
    print('Connect charger')
# Out:
# Is your charger connected (yes/no):  YeS
# What is your battery percentage 100
# Battery Full

# %% [markdown]
# ## A traffic system calculates fines:
#
# Speed limit = 60 km/h
# * If speed ≤ 60 → No fine
# * If 61–80 → Fine = 500
# * If 81–100 → Fine = 2000
# * If >100 → License suspended
# #### BUT:
# *If emergency vehicle → no fine
# *If rainy weather AND speed > 60 → fine increases by 50%

# %%
speed_limit = 60
user_speed = int(input('Enter your Vehicle Speed: '))
emergency_vehicle = input('Is this an emergency vehicle (yes/no): ').lower()
fine = 0

if user_speed<=speed_limit or emergency_vehicle == 'yes':
    print('No fine') 
else:
    rainy_weather = input('Is this a rainy weather (yes/no): ').lower()
    if user_speed<=80:
        fine += 500
    elif user_speed<=100:
        fine += 2000
    else:
        print('License suspended')

    if rainy_weather =='yes' and fine>0:
        fine = int(fine*1.5)
    else:
        pass
print(f'Fine = {fine}')
# Out:
# Enter your Vehicle Speed:  95
# Is this an emergency vehicle (yes/no):  no
# Is this a rainy weather (yes/no):  yes
# Fine = 3000

# %% [markdown]
# ## A company filters candidates:
# * Experience ≥ 5 years AND skill score ≥ 80 → shortlisted
# * Experience 2–4 years AND skill score ≥ 70 → interview
# * Freshers → only if test score ≥ 85
# * If criminal record = True → reject immediately
# * If multiple job switches (>3 in 2 years) → flag as unstable

# %%
criminal_record = input('Do you have any criminal record(yes/no): ')
if criminal_record =='no':
    multiple_job_switches = int(input('How many jobs do you switched in 2 years: '))
    if multiple_job_switches<3:
        experience = int(input('Enter your experiance(number of years): '))
        score = int(input('Enter your Score: '))
        if experience >=5 and score>=80:
            print('Shortlisted')
        elif experience>=2 and experience<=4 and score>=70:
            print('Interview')
        elif experience == 0 and score>=85:
            print('Interview')
        else:
            print('You can not meet the required criteria')
    else:
        print('Unstable')
else:
    print('Reject immediately')
# Out:
# Do you have any criminal record(yes/no):  no
# How many jobs do you switched in 2 years:  3
# Unstable

# %% [markdown]
# ## Write a program to decide passenger clearance status.
# Take input:
# * baggage_weight
# * passport_valid (Yes/No)
# * visa_status (Valid/Invalid)
# * criminal_check (Clear/Flagged)
# #### Rules:
# * baggage > 30kg → extra charge
# * passport invalid → reject
# * visa invalid → reject
# * criminal flagged → security hold
# * otherwise → cleared for boarding

# %%
passport_valid = input('Is your passport valid (Yes/No): ').lower() 
visa_status = input('What is your visa status (Valid/Invalid): ') 
if passport_valid =='no' or visa_status =='invalid':
    print('Rejected')
else:
    criminal_check = input('What is your criminal record (Clear/Flagged): ').lower()
    baggage_weight = int(input('Enter your baggage Weight: '))
    if criminal_check == 'flagged':
        print('Security hold')        
    else:
        if baggage_weight> 30:
            print('Extra charge')
        print("Cleared for boarding")
# Out:
# Is your passport valid (Yes/No):  yes
# What is your visa status (Valid/Invalid):  valid
# What is your criminal record (Clear/Flagged):  clear
# Enter your baggage Weight:  25
# Cleared for boarding

# %% [markdown]
# ## Write a program to decide insurance eligibility.
# Take input:
# * age
# * smoker (Yes/No)
# * existing_disease (Yes/No)
# * annual_income
# #### Rules:
# * age < 18 → reject
# * smoker + disease → high premium category
# * income < 200000 → limited coverage
# * age > 60 → special medical check required
# * otherwise → normal approval

# %%
age = int(input('Enter your age: '))
if age<18:
    print('Rejected')
else:
    annual_income = int(input('What is your annual income: '))
    smoker = input('Are you a smoker(Yes/No):').lower()
    existing_disease =input('Do you have any diseases (Yes/No): ').lower()
    if annual_income < 200000:
        print('Limited coverage: ')
    elif smoker =='yes' and existing_disease =='yes':
        print("high premium category")
    elif age> 60:
         print('Special medical check required')
    else:
        print('normal approval')
# Out:
# Enter your age:  68
# What is your annual income:  600000
# Are you a smoker(Yes/No): no
# Do you have any diseases (Yes/No):  no
# Special medical check required

# %% [markdown]
# ## Write a program to detect suspicious banking transactions.
# Take input:
# * transaction_amount
# * location_match (Yes/No)
# * time_of_transaction(Day/Night)
# * previous_transactions_count
# * device_verified (Yes/No)
# #### Rules:
# * amount > 100,000 → suspicious
# * location mismatch + high amount → fraud alert
# * night transaction + unverified device → high risk
# * many transactions (>10 in 1 hour) → freeze account
# * otherwise → normal transaction

# %%
previous_transactions_count = int(input("How many transictions in 1 hour: "))
if previous_transactions_count > 10:
    print('Freeze account')
else:
    time_of_transaction = input("What is the time of transactions (Day/Night) ").lower()
    device_verified = input('Is the device varified (Yes/No)').lower()
    if time_of_transaction == 'night' and device_verified =='no':
        print('high risk')
    else:
        transaction_amount = int(input('What is the transiction amount: '))
        if transaction_amount> 100000:
            print('Suspicious')
        else:
            print('normal transaction ')
# Out:
# How many transictions in 1 hour:  5
# What is the time of transactions (Day/Night)  day
# Is the device varified (Yes/No) yes
# What is the transiction amount:  1000000
# Suspicious

# %% [markdown]
# ## Write a program to classify a person’s risk level in a police database.
# Take input:
# * criminal_record (Yes/No)
# * number_of_cases
# * travel_history_flagged (Yes/No)
# * financial_activity_score
# * last_activity_days
# #### Rules:
# * criminal_record = Yes AND cases > 3 → High Risk
# * flagged travel + suspicious financial score → High Risk
# * no activity for long time (>365 days) → Monitor
# * clean record + normal activity → Low Risk
# * mixed signals → Medium Risk

# %%
criminal_record = input('Do you have any criminal records (Yes/No): ').lower()
number_of_cases = int(input('How many number of cases do you have: '))
if criminal_record == 'yes' and number_of_cases > 3:
    print('High Risk')
else:
    last_activity_days = int(input('What is the last activity days: '))
    if last_activity_days > 365:
        print('Monitor')
    else:
        travel_history_flagged = input('Is your travel history flagged (Yes/No): ').lower()
        financial_activity_score = int(input('What is the financial activity score (0 to 100): '))
        if travel_history_flagged == 'yes' and financial_activity_score < 40:
            print('High Risk')
        elif criminal_record == 'no' and financial_activity_score >= 70:
            print('Low Risk')
        else:
            print('Medium Risk')
# Out:
# Do you have any criminal records (Yes/No):  no
# How many number of cases do you have:  04
# What is the last activity days:  333
# Is your travel history flagged (Yes/No):  yes
# What is the financial activity score (0 to 100):  76
# Low Risk

# %% [markdown]
# OR

# %%
criminal_record = input('Do you have any criminal records (Yes/No): ').lower()
number_of_cases = int(input('How many number of cases do you have: '))
travel_history_flagged = input('Is your travel history flagged (Yes/No): ').lower()
financial_activity_score = int(input('What is the financial activity score (0 to 100): '))
last_activity_days = int(input('What is the last activity days: '))

if criminal_record == 'yes' and number_of_cases > 3:
    print('High Risk')
elif travel_history_flagged == 'yes' and financial_activity_score < 40:
    print('High Risk')
elif last_activity_days > 365:
    print('Monitor')
elif criminal_record == 'no' and financial_activity_score >= 70:
    print('Low Risk')
else:
    print('Medium Risk')
# Out:
# Do you have any criminal records (Yes/No):  yes
# How many number of cases do you have:  56
# Is your travel history flagged (Yes/No):  no
# What is the financial activity score (0 to 100):  76
# What is the last activity days:  400
# High Risk
