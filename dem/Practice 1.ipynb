# %% [markdown]
# ### Practice Questions

# %%
# 1. creat a list of 5 numbers and add one more number

# %%
number_list = [1, 6, 7, 8, 3]
print(number_list)
# Out:
# [1, 6, 7, 8, 3]

# %%
number_list.append(2)
print(number_list)
# Out:
# [1, 6, 7, 8, 3, 2]

# %%
number_list.insert(2, 5)
print(number_list)
# Out:
# [1, 6, 5, 7, 8, 3, 2]

# %%
# 2. creat a tuple of 3 cities and print the second city

# %%
cities_tuple = ("Skardu", "Karachi", "Islamabad")
print(cities_tuple)
print(cities_tuple[1])
# Out:
# ('Skardu', 'Karachi', 'Islamabad')
# Karachi

# %%
# 3. create two sets and find their intersection

# %%
set_1 = {1,4,8,45,32}
set_2 = {1,8,33,43,2}
print(set_1.intersection(set_2))
# Out:
# {8, 1}

# %%
# 4. create a dictionary of your own details and print all keys

# %%
my_details={
    "name" : "Ali",
    "age" : 25,
    "qualification" : "BS Physics",
    "cgp" : 3.76
}
for key, value in my_details.items():
    print(key, " = " , value)
# Out:
# name  =  Ali
# age  =  25
# qualification  =  BS Physics
# cgp  =  3.76

# %%
# Write a Python expression that evaluates to True if a given integer x is even and greater than 100, otherwise False. Test your expression with x = 102 and x = 99.

# %%
x = 102
result = (x>100) and (x/2==0)
print(result)
